# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import numpy as np
import csv
import random
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
import numpy as np
import matplotlib.pyplot as plt
import csv
import matplotlib.gridspec as gridspec
import time as chrono


from BSE import market_session
from BSE import market_session_event_driven

# Simulation parameters
start_time = 0
end_time = 60 * 20   # 10 minutes = 600 seconds
order_interval = 10  # Order generation interval in seconds

quantity = 10
sellers_spec = [('PRZI', quantity)]
buyers_spec  = [('PRZI', quantity)]
traders_spec = {'sellers': sellers_spec, 'buyers': buyers_spec}

# Define normal, crash, and upward price ranges.
normal_range = (100, 190)
crash_range  = (50, 80)      # For downward shock (crash)
upward_range = (300, 350)    # For upward shock (bubble)

# Global shock variables
shock_active = False
shock_end_time = 0
shock_type = None         # "down" for crash, "up" for upward shock
base_shock_duration = 40  # Base shock duration if threshold is exactly met
min_shock_duration = 20
max_shock_duration = 120
last_trade_price = None

# We'll collect shock events here
shock_events = []  # Each event is a dict: {'time': <shock start time>, 'type': 'down' or 'up'}

def get_active_range(current_time):
    """
    Returns the active price range based on the current simulation time.
    Uses the appropriate shock range if a shock is active.
    """
    global shock_active, shock_end_time, shock_type
    if shock_active and current_time < shock_end_time:
        if shock_type == "down":
            return crash_range
        elif shock_type == "up":
            return upward_range
    return normal_range

# For this example we use a static order schedule using the normal range.
sup_sched = [{'from': 0, 'to': end_time, 'ranges': [normal_range], 'stepmode': 'random'}]
dem_sched = sup_sched.copy()

order_schedule = {
    'sup': sup_sched,
    'dem': dem_sched,
    'interval': order_interval,
    'timemode': 'drip-poisson', #periodic also works well
    'fittointerval': False
}

verbose = False
dump_flags = {
    'dump_blotters': True,
    'dump_lobs': True,
    'dump_strats': True,
    'dump_avgbals': True,
    'dump_tape': True
}

n_sessions = 1
x = np.empty(0)
y = np.empty(0)

# Run the simulation session(s)
for sess in range(n_sessions):
    trial_id = 'new_trader_chart_' + str(sess)
    
    # Run the market session (in practice, your order-generation could use get_active_range(current_time)).
    market_session(trial_id, start_time, end_time, traders_spec, order_schedule, dump_flags, verbose)
    
    # Read the trade tape and detect shocks.
    prices_fname = trial_id + '_tape.csv'
    with open(prices_fname, newline='') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            current_time = float(row[1])
            price = float(row[2])
            x = np.append(x, current_time)
            y = np.append(y, price)
            
            if last_trade_price is not None:
                # Check for a downward shock (price drop of more than 5%)
                if price < 0.9 * last_trade_price:
                    drop_pct = (last_trade_price - price) / last_trade_price
                    adaptive_duration = base_shock_duration * (drop_pct / 0.05)
                    adaptive_duration = np.clip(adaptive_duration, min_shock_duration, max_shock_duration)
                    
                    shock_active = True
                    shock_type = "down"
                    shock_end_time = current_time + adaptive_duration
                    print(f"Downward shock triggered at {current_time:.2f}s: price dropped from {last_trade_price:.2f} to {price:.2f}")
                    print(f"Adaptive downward shock duration: {adaptive_duration:.2f}s (ends at {shock_end_time:.2f}s)")
                    shock_events.append({'time': current_time, 'type': shock_type})
                
                # Check for an upward shock (price increase of more than 10%)
                elif price > 1.10 * last_trade_price:
                    increase_pct = (price - last_trade_price) / last_trade_price
                    adaptive_duration = base_shock_duration * (increase_pct / 0.10)
                    adaptive_duration = np.clip(adaptive_duration, min_shock_duration, max_shock_duration)
                    
                    shock_active = True
                    shock_type = "up"
                    shock_end_time = current_time + adaptive_duration
                    print(f"Upward shock triggered at {current_time:.2f}s: price increased from {last_trade_price:.2f} to {price:.2f}")
                    print(f"Adaptive upward shock duration: {adaptive_duration:.2f}s (ends at {shock_end_time:.2f}s)")
                    shock_events.append({'time': current_time, 'type': shock_type})
            last_trade_price = price

# Plot the trade prices over time
plt.figure(figsize=(20, 6))
plt.plot(x, y, 'x', color='black', linestyle='dashed', label="Trade Price")

# Plot vertical dashed lines for each shock event.
for event in shock_events:
    if event['type'] == "down":
        plt.axvline(x=event['time'], color='red', linestyle='--', linewidth=2, alpha = 0.2,
                    label="Downward Shock" if 'Downward Shock' not in plt.gca().get_legend_handles_labels()[1] else "")
    elif event['type'] == "up":
        plt.axvline(x=event['time'], color='blue', linestyle='--', linewidth=2, alpha = 0.2,
                    label="Upward Shock" if 'Upward Shock' not in plt.gca().get_legend_handles_labels()[1] else "")

plt.xlabel("Time (s)")
plt.ylabel("Price")
plt.title("Market Prices with Adaptive Upward and Downward Shocks")
plt.legend()
plt.ylim(0,300)
plt.show()
# Out:
# B00: PRZI active_strat=[0]:
# [0]: s=-0.311388, start=0.000000, $=0.000000, pps=0.000000
#
#
# B01: PRZI active_strat=[0]:
# [0]: s=+0.213955, start=0.000000, $=0.000000, pps=0.000000
#
#
# B02: PRZI active_strat=[0]:
# [0]: s=+0.641708, start=0.000000, $=0.000000, pps=0.000000
#
#
# B03: PRZI active_strat=[0]:
# [0]: s=-0.081174, start=0.000000, $=0.000000, pps=0.000000
#
#
# B04: PRZI active_strat=[0]:
# [0]: s=+0.974555, start=0.000000, $=0.000000, pps=0.000000
#
#
# B05: PRZI active_strat=[0]:
# [0]: s=-0.384470, start=0.000000, $=0.000000, pps=0.000000
#
#
# B06: PRZI active_strat=[0]:
# [0]: s=+0.394156, start=0.000000, $=0.000000, pps=0.000000
#
#
# B07: PRZI active_strat=[0]:
# [0]: s=-0.500618, start=0.000000, $=0.000000, pps=0.000000
#
#
# B08: PRZI active_strat=[0]:
# [0]: s=-0.202658, start=0.000000, $=0.000000, pps=0.000000
#
#
# B09: PRZI active_strat=[0]:
# [0]: s=-0.973086, start=0.000000, $=0.000000, pps=0.000000
#
#
# S00: PRZI active_strat=[0]:
# [0]: s=+0.121758, start=0.000000, $=0.000000, pps=0.000000
#
#
# S01: PRZI active_strat=[0]:
# [0]: s=+0.250016, start=0.000000, $=0.000000, pps=0.000000
#
#
# S02: PRZI active_strat=[0]:
# [0]: s=+0.517236, start=0.000000, $=0.000000, pps=0.000000
#
#
# S03: PRZI active_strat=[0]:
# [0]: s=+0.555364, start=0.000000, $=0.000000, pps=0.000000
#
#
# S04: PRZI active_strat=[0]:
# [0]: s=-0.107454, start=0.000000, $=0.000000, pps=0.000000
#
#
# S05: PRZI active_strat=[0]:
# [0]: s=-0.377242, start=0.000000, $=0.000000, pps=0.000000
#
#
# S06: PRZI active_strat=[0]:
# [0]: s=-0.776970, start=0.000000, $=0.000000, pps=0.000000
#
#
# S07: PRZI active_strat=[0]:
# [0]: s=-0.220834, start=0.000000, $=0.000000, pps=0.000000
#
#
# S08: PRZI active_strat=[0]:
# [0]: s=+0.396656, start=0.000000, $=0.000000, pps=0.000000
#
#
# S09: PRZI active_strat=[0]:
# [0]: s=+0.821114, start=0.000000, $=0.000000, pps=0.000000
#
#
# Downward shock triggered at 24.45s: price dropped from 149.00 to 122.00
# Adaptive downward shock duration: 120.00s (ends at 144.45s)
# Upward shock triggered at 36.65s: price increased from 122.00 to 138.00
# Adaptive upward shock duration: 52.46s (ends at 89.11s)
# Upward shock triggered at 60.35s: price increased from 129.00 to 160.00
# Adaptive upward shock duration: 96.12s (ends at 156.47s)
# Upward shock triggered at 90.75s: price increased from 144.00 to 168.00
# Adaptive upward shock duration: 66.67s (ends at 157.42s)
# Downward shock triggered at 93.00s: price dropped from 168.00 to 143.00
# Adaptive downward shock duration: 119.05s (ends at 212.05s)
# Upward shock triggered at 100.00s: price increased from 141.00 to 164.00
# Adaptive upward shock duration: 65.25s (ends at 165.25s)
# Downward shock triggered at 106.75s: price dropped from 164.00 to 143.00
# Adaptive downward shock duration: 102.44s (ends at 209.19s)
# Upward shock triggered at 109.85s: price increased from 143.00 to 169.00
# Adaptive upward shock duration: 72.73s (ends at 182.58s)
# Downward shock triggered at 110.60s: price dropped from 169.00 to 146.00
# Adaptive downward shock duration: 108.88s (ends at 219.48s)
# Upward shock triggered at 114.55s: price increased from 146.00 to 177.00
# Adaptive upward shock duration: 84.93s (ends at 199.48s)
# Downward shock triggered at 118.75s: price dropped from 177.00 to 145.00
# Adaptive downward shock duration: 120.00s (ends at 238.75s)
# Upward shock triggered at 123.65s: price increased from 136.00 to 170.00
# Adaptive upward shock duration: 100.00s (ends at 223.65s)
# Downward shock triggered at 134.30s: price dropped from 170.00 to 152.00
# Adaptive downward shock duration: 84.71s (ends at 219.01s)
# Upward shock triggered at 151.10s: price increased from 146.00 to 167.00
# Adaptive upward shock duration: 57.53s (ends at 208.63s)
# Downward shock triggered at 154.85s: price dropped from 167.00 to 120.00
# Adaptive downward shock duration: 120.00s (ends at 274.85s)
# Upward shock triggered at 162.45s: price increased from 125.00 to 162.00
# Adaptive upward shock duration: 118.40s (ends at 280.85s)
# Downward shock triggered at 167.45s: price dropped from 162.00 to 122.00
# Adaptive downward shock duration: 120.00s (ends at 287.45s)
# Upward shock triggered at 176.75s: price increased from 125.00 to 140.00
# Adaptive upward shock duration: 48.00s (ends at 224.75s)
# Upward shock triggered at 180.80s: price increased from 141.00 to 160.00
# Adaptive upward shock duration: 53.90s (ends at 234.70s)
# Downward shock triggered at 183.15s: price dropped from 160.00 to 129.00
# Adaptive downward shock duration: 120.00s (ends at 303.15s)
# Upward shock triggered at 183.60s: price increased from 129.00 to 151.00
# Adaptive upward shock duration: 68.22s (ends at 251.82s)
# Upward shock triggered at 187.65s: price increased from 151.00 to 180.00
# Adaptive upward shock duration: 76.82s (ends at 264.47s)
# Downward shock triggered at 190.80s: price dropped from 180.00 to 129.00
# Adaptive downward shock duration: 120.00s (ends at 310.80s)
# Upward shock triggered at 195.60s: price increased from 129.00 to 163.00
# Adaptive upward shock duration: 105.43s (ends at 301.03s)
# Downward shock triggered at 212.05s: price dropped from 171.00 to 136.00
# Adaptive downward shock duration: 120.00s (ends at 332.05s)
# Downward shock triggered at 224.50s: price dropped from 136.00 to 111.00
# Adaptive downward shock duration: 120.00s (ends at 344.50s)
# Upward shock triggered at 226.15s: price increased from 111.00 to 157.00
# Adaptive upward shock duration: 120.00s (ends at 346.15s)
# Downward shock triggered at 228.05s: price dropped from 157.00 to 126.00
# Adaptive downward shock duration: 120.00s (ends at 348.05s)
# Upward shock triggered at 236.60s: price increased from 118.00 to 155.00
# Adaptive upward shock duration: 120.00s (ends at 356.60s)
# Downward shock triggered at 248.10s: price dropped from 177.00 to 153.00
# Adaptive downward shock duration: 108.47s (ends at 356.57s)
# Downward shock triggered at 256.80s: price dropped from 140.00 to 124.00
# Adaptive downward shock duration: 91.43s (ends at 348.23s)
# Upward shock triggered at 257.20s: price increased from 124.00 to 158.00
# Adaptive upward shock duration: 109.68s (ends at 366.88s)
# Downward shock triggered at 261.80s: price dropped from 158.00 to 126.00
# Adaptive downward shock duration: 120.00s (ends at 381.80s)
# Upward shock triggered at 277.90s: price increased from 121.00 to 168.00
# Adaptive upward shock duration: 120.00s (ends at 397.90s)
# Downward shock triggered at 281.75s: price dropped from 168.00 to 143.00
# Adaptive downward shock duration: 119.05s (ends at 400.80s)
# Upward shock triggered at 285.40s: price increased from 143.00 to 171.00
# Adaptive upward shock duration: 78.32s (ends at 363.72s)
# Downward shock triggered at 302.10s: price dropped from 173.00 to 145.00
# Adaptive downward shock duration: 120.00s (ends at 422.10s)
# Downward shock triggered at 336.10s: price dropped from 156.00 to 139.00
# Adaptive downward shock duration: 87.18s (ends at 423.28s)
# Upward shock triggered at 342.65s: price increased from 128.00 to 164.00
# Adaptive upward shock duration: 112.50s (ends at 455.15s)
# Downward shock triggered at 350.65s: price dropped from 176.00 to 157.00
# Adaptive downward shock duration: 86.36s (ends at 437.01s)
# Downward shock triggered at 351.05s: price dropped from 157.00 to 136.00
# Adaptive downward shock duration: 107.01s (ends at 458.06s)
# Upward shock triggered at 366.75s: price increased from 131.00 to 150.00
# Adaptive upward shock duration: 58.02s (ends at 424.77s)
# Downward shock triggered at 367.25s: price dropped from 150.00 to 131.00
# Adaptive downward shock duration: 101.33s (ends at 468.58s)
# Upward shock triggered at 385.60s: price increased from 131.00 to 147.00
# Adaptive upward shock duration: 48.85s (ends at 434.45s)
# Downward shock triggered at 387.75s: price dropped from 147.00 to 123.00
# Adaptive downward shock duration: 120.00s (ends at 507.75s)
# Upward shock triggered at 402.00s: price increased from 123.00 to 169.00
# Adaptive upward shock duration: 120.00s (ends at 522.00s)
# Downward shock triggered at 416.05s: price dropped from 169.00 to 149.00
# Adaptive downward shock duration: 94.67s (ends at 510.72s)
# Upward shock triggered at 418.75s: price increased from 149.00 to 171.00
# Adaptive upward shock duration: 59.06s (ends at 477.81s)
# Downward shock triggered at 419.80s: price dropped from 171.00 to 123.00
# Adaptive downward shock duration: 120.00s (ends at 539.80s)
# Upward shock triggered at 423.50s: price increased from 123.00 to 156.00
# Adaptive upward shock duration: 107.32s (ends at 530.82s)
# Downward shock triggered at 434.25s: price dropped from 180.00 to 155.00
# Adaptive downward shock duration: 111.11s (ends at 545.36s)
# Upward shock triggered at 443.60s: price increased from 146.00 to 161.00
# Adaptive upward shock duration: 41.10s (ends at 484.70s)
# Downward shock triggered at 463.10s: price dropped from 162.00 to 135.00
# Adaptive downward shock duration: 120.00s (ends at 583.10s)
# Upward shock triggered at 469.25s: price increased from 135.00 to 156.00
# Adaptive upward shock duration: 62.22s (ends at 531.47s)
# Downward shock triggered at 474.25s: price dropped from 147.00 to 118.00
# Adaptive downward shock duration: 120.00s (ends at 594.25s)
# Upward shock triggered at 478.80s: price increased from 118.00 to 151.00
# Adaptive upward shock duration: 111.86s (ends at 590.66s)
# Upward shock triggered at 487.65s: price increased from 147.00 to 184.00
# Adaptive upward shock duration: 100.68s (ends at 588.33s)
# Downward shock triggered at 489.05s: price dropped from 184.00 to 145.00
# Adaptive downward shock duration: 120.00s (ends at 609.05s)
# Upward shock triggered at 505.75s: price increased from 143.00 to 161.00
# Adaptive upward shock duration: 50.35s (ends at 556.10s)
# Upward shock triggered at 512.45s: price increased from 161.00 to 179.00
# Adaptive upward shock duration: 44.72s (ends at 557.17s)
# Downward shock triggered at 518.70s: price dropped from 164.00 to 137.00
# Adaptive downward shock duration: 120.00s (ends at 638.70s)
# Upward shock triggered at 536.50s: price increased from 132.00 to 147.00
# Adaptive upward shock duration: 45.45s (ends at 581.95s)
# Upward shock triggered at 550.15s: price increased from 147.00 to 170.00
# Adaptive upward shock duration: 62.59s (ends at 612.74s)
# Downward shock triggered at 553.50s: price dropped from 170.00 to 152.00
# Adaptive downward shock duration: 84.71s (ends at 638.21s)
# Upward shock triggered at 566.75s: price increased from 142.00 to 161.00
# Adaptive upward shock duration: 53.52s (ends at 620.27s)
# Upward shock triggered at 583.40s: price increased from 141.00 to 158.00
# Adaptive upward shock duration: 48.23s (ends at 631.63s)
# Downward shock triggered at 587.10s: price dropped from 158.00 to 135.00
# Adaptive downward shock duration: 116.46s (ends at 703.56s)
# Upward shock triggered at 589.85s: price increased from 135.00 to 160.00
# Adaptive upward shock duration: 74.07s (ends at 663.92s)
# Upward shock triggered at 614.90s: price increased from 157.00 to 178.00
# Adaptive upward shock duration: 53.50s (ends at 668.40s)
# Downward shock triggered at 617.85s: price dropped from 181.00 to 155.00
# Adaptive downward shock duration: 114.92s (ends at 732.77s)
# Downward shock triggered at 671.80s: price dropped from 165.00 to 141.00
# Adaptive downward shock duration: 116.36s (ends at 788.16s)
# Upward shock triggered at 695.25s: price increased from 141.00 to 168.00
# Adaptive upward shock duration: 76.60s (ends at 771.85s)
# Downward shock triggered at 696.00s: price dropped from 168.00 to 135.00
# Adaptive downward shock duration: 120.00s (ends at 816.00s)
# Upward shock triggered at 702.45s: price increased from 136.00 to 152.00
# Adaptive upward shock duration: 47.06s (ends at 749.51s)
# Upward shock triggered at 704.75s: price increased from 152.00 to 170.00
# Adaptive upward shock duration: 47.37s (ends at 752.12s)
# Downward shock triggered at 709.15s: price dropped from 167.00 to 136.00
# Adaptive downward shock duration: 120.00s (ends at 829.15s)
# Upward shock triggered at 720.85s: price increased from 131.00 to 153.00
# Adaptive upward shock duration: 67.18s (ends at 788.03s)
# Upward shock triggered at 728.95s: price increased from 133.00 to 149.00
# Adaptive upward shock duration: 48.12s (ends at 777.07s)
# Downward shock triggered at 731.00s: price dropped from 149.00 to 126.00
# Adaptive downward shock duration: 120.00s (ends at 851.00s)
# Upward shock triggered at 735.30s: price increased from 126.00 to 168.00
# Adaptive upward shock duration: 120.00s (ends at 855.30s)
# Downward shock triggered at 735.65s: price dropped from 168.00 to 140.00
# Adaptive downward shock duration: 120.00s (ends at 855.65s)
# Upward shock triggered at 740.90s: price increased from 140.00 to 175.00
# Adaptive upward shock duration: 100.00s (ends at 840.90s)
# Downward shock triggered at 741.40s: price dropped from 175.00 to 129.00
# Adaptive downward shock duration: 120.00s (ends at 861.40s)
# Upward shock triggered at 748.80s: price increased from 129.00 to 145.00
# Adaptive upward shock duration: 49.61s (ends at 798.41s)
# Upward shock triggered at 755.15s: price increased from 145.00 to 168.00
# Adaptive upward shock duration: 63.45s (ends at 818.60s)
# Downward shock triggered at 757.65s: price dropped from 168.00 to 142.00
# Adaptive downward shock duration: 120.00s (ends at 877.65s)
# Upward shock triggered at 766.00s: price increased from 142.00 to 158.00
# Adaptive upward shock duration: 45.07s (ends at 811.07s)
# Upward shock triggered at 796.95s: price increased from 141.00 to 156.00
# Adaptive upward shock duration: 42.55s (ends at 839.50s)
# Downward shock triggered at 808.10s: price dropped from 154.00 to 137.00
# Adaptive downward shock duration: 88.31s (ends at 896.41s)
# Upward shock triggered at 812.55s: price increased from 137.00 to 181.00
# Adaptive upward shock duration: 120.00s (ends at 932.55s)
# Downward shock triggered at 814.60s: price dropped from 181.00 to 158.00
# Adaptive downward shock duration: 101.66s (ends at 916.26s)
# Downward shock triggered at 821.15s: price dropped from 169.00 to 118.00
# Adaptive downward shock duration: 120.00s (ends at 941.15s)
# Upward shock triggered at 825.90s: price increased from 118.00 to 138.00
# Adaptive upward shock duration: 67.80s (ends at 893.70s)
# Upward shock triggered at 828.95s: price increased from 138.00 to 152.00
# Adaptive upward shock duration: 40.58s (ends at 869.53s)
# Upward shock triggered at 831.60s: price increased from 152.00 to 179.00
# Adaptive upward shock duration: 71.05s (ends at 902.65s)
# Downward shock triggered at 832.65s: price dropped from 179.00 to 154.00
# Adaptive downward shock duration: 111.73s (ends at 944.38s)
# Downward shock triggered at 837.10s: price dropped from 166.00 to 136.00
# Adaptive downward shock duration: 120.00s (ends at 957.10s)
# Upward shock triggered at 848.75s: price increased from 136.00 to 171.00
# Adaptive upward shock duration: 102.94s (ends at 951.69s)
# Downward shock triggered at 872.40s: price dropped from 169.00 to 152.00
# Adaptive downward shock duration: 80.47s (ends at 952.87s)
# Downward shock triggered at 874.70s: price dropped from 152.00 to 127.00
# Adaptive downward shock duration: 120.00s (ends at 994.70s)
# Upward shock triggered at 884.95s: price increased from 137.00 to 152.00
# Adaptive upward shock duration: 43.80s (ends at 928.75s)
# Upward shock triggered at 892.30s: price increased from 152.00 to 176.00
# Adaptive upward shock duration: 63.16s (ends at 955.46s)
# Downward shock triggered at 894.60s: price dropped from 176.00 to 132.00
# Adaptive downward shock duration: 120.00s (ends at 1014.60s)
# Upward shock triggered at 897.75s: price increased from 132.00 to 158.00
# Adaptive upward shock duration: 78.79s (ends at 976.54s)
# Downward shock triggered at 903.45s: price dropped from 158.00 to 137.00
# Adaptive downward shock duration: 106.33s (ends at 1009.78s)
# Upward shock triggered at 904.85s: price increased from 137.00 to 179.00
# Adaptive upward shock duration: 120.00s (ends at 1024.85s)
# Downward shock triggered at 909.10s: price dropped from 179.00 to 140.00
# Adaptive downward shock duration: 120.00s (ends at 1029.10s)
# Upward shock triggered at 914.15s: price increased from 140.00 to 168.00
# Adaptive upward shock duration: 80.00s (ends at 994.15s)
# Downward shock triggered at 919.40s: price dropped from 168.00 to 118.00
# Adaptive downward shock duration: 120.00s (ends at 1039.40s)
# Upward shock triggered at 926.55s: price increased from 118.00 to 145.00
# Adaptive upward shock duration: 91.53s (ends at 1018.08s)
# Upward shock triggered at 937.80s: price increased from 142.00 to 161.00
# Adaptive upward shock duration: 53.52s (ends at 991.32s)
# Downward shock triggered at 941.90s: price dropped from 161.00 to 140.00
# Adaptive downward shock duration: 104.35s (ends at 1046.25s)
# Upward shock triggered at 954.65s: price increased from 125.00 to 163.00
# Adaptive upward shock duration: 120.00s (ends at 1074.65s)
# Downward shock triggered at 966.75s: price dropped from 172.00 to 138.00
# Adaptive downward shock duration: 120.00s (ends at 1086.75s)
# Upward shock triggered at 972.00s: price increased from 138.00 to 160.00
# Adaptive upward shock duration: 63.77s (ends at 1035.77s)
# Downward shock triggered at 980.50s: price dropped from 145.00 to 120.00
# Adaptive downward shock duration: 120.00s (ends at 1100.50s)
# Upward shock triggered at 983.50s: price increased from 120.00 to 151.00
# Adaptive upward shock duration: 103.33s (ends at 1086.83s)
# Upward shock triggered at 998.95s: price increased from 143.00 to 175.00
# Adaptive upward shock duration: 89.51s (ends at 1088.46s)
# Downward shock triggered at 1002.30s: price dropped from 175.00 to 146.00
# Adaptive downward shock duration: 120.00s (ends at 1122.30s)
# Downward shock triggered at 1006.75s: price dropped from 146.00 to 127.00
# Adaptive downward shock duration: 104.11s (ends at 1110.86s)
# Upward shock triggered at 1007.70s: price increased from 127.00 to 172.00
# Adaptive upward shock duration: 120.00s (ends at 1127.70s)
# Downward shock triggered at 1021.70s: price dropped from 182.00 to 143.00
# Adaptive downward shock duration: 120.00s (ends at 1141.70s)
# Downward shock triggered at 1034.65s: price dropped from 150.00 to 129.00
# Adaptive downward shock duration: 112.00s (ends at 1146.65s)
# Upward shock triggered at 1037.20s: price increased from 129.00 to 154.00
# Adaptive upward shock duration: 77.52s (ends at 1114.72s)
# Upward shock triggered at 1062.05s: price increased from 140.00 to 166.00
# Adaptive upward shock duration: 74.29s (ends at 1136.34s)
# Downward shock triggered at 1062.55s: price dropped from 166.00 to 148.00
# Adaptive downward shock duration: 86.75s (ends at 1149.30s)
# Downward shock triggered at 1072.85s: price dropped from 148.00 to 132.00
# Adaptive downward shock duration: 86.49s (ends at 1159.34s)
# Upward shock triggered at 1074.85s: price increased from 132.00 to 177.00
# Adaptive upward shock duration: 120.00s (ends at 1194.85s)
# Downward shock triggered at 1084.55s: price dropped from 177.00 to 148.00
# Adaptive downward shock duration: 120.00s (ends at 1204.55s)
# Upward shock triggered at 1086.55s: price increased from 148.00 to 171.00
# Adaptive upward shock duration: 62.16s (ends at 1148.71s)
# Downward shock triggered at 1087.45s: price dropped from 171.00 to 125.00
# Adaptive downward shock duration: 120.00s (ends at 1207.45s)
# Upward shock triggered at 1097.90s: price increased from 120.00 to 140.00
# Adaptive upward shock duration: 66.67s (ends at 1164.57s)
# Upward shock triggered at 1099.20s: price increased from 140.00 to 165.00
# Adaptive upward shock duration: 71.43s (ends at 1170.63s)
# Downward shock triggered at 1115.75s: price dropped from 157.00 to 126.00
# Adaptive downward shock duration: 120.00s (ends at 1235.75s)
# Upward shock triggered at 1118.25s: price increased from 126.00 to 146.00
# Adaptive upward shock duration: 63.49s (ends at 1181.74s)
# Downward shock triggered at 1123.90s: price dropped from 156.00 to 118.00
# Adaptive downward shock duration: 120.00s (ends at 1243.90s)
# Upward shock triggered at 1126.75s: price increased from 118.00 to 144.00
# Adaptive upward shock duration: 88.14s (ends at 1214.89s)
# Downward shock triggered at 1141.15s: price dropped from 154.00 to 128.00
# Adaptive downward shock duration: 120.00s (ends at 1261.15s)
# Upward shock triggered at 1142.85s: price increased from 128.00 to 150.00
# Adaptive upward shock duration: 68.75s (ends at 1211.60s)
# Downward shock triggered at 1174.35s: price dropped from 167.00 to 150.00
# Adaptive downward shock duration: 81.44s (ends at 1255.79s)
# Upward shock triggered at 1182.85s: price increased from 133.00 to 165.00
# Adaptive upward shock duration: 96.24s (ends at 1279.09s)
